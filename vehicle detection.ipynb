# %% [markdown]
# <a href="https://colab.research.google.com/github/Gurunr1234/dem/blob/main/vehicle%20detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/yolov8n-oiv7 (1).pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model("/content/im.jpg")  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="1.jpg")  # save to disk
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# image 1/1 /content/im.jpg: 448x640 5 Cars, 1 Land vehicle, 458.8ms
# Speed: 19.4ms preprocess, 458.8ms inference, 38.5ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=270x180>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 23.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2

# Load the YOLOv8 model
model = YOLO("/content/yolov8n-oiv7 (1).pt")  # Adjust path to your YOLOv8 model

# Define video input and output
video_path = "/content/Test Video.mp4"  # Path to your input video
output_path = "output_video.mp4"  # Path to save the output video

# Open the video file
cap = cv2.VideoCapture(video_path)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the video writer for saving the output
out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

# Process the video frame by frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # Exit if the video ends

    # Perform inference on the current frame
    results = model(frame)

    # Visualize the results on the frame
    annotated_frame = results[0].plot()  # Annotate the frame with predictions

    # Write the annotated frame to the output video
    out.write(annotated_frame)

    # Optionally display the frame (uncomment to see in real-time)
    # cv2.imshow('Frame', annotated_frame)
    # if cv2.waitKey(1) & 0xFF == ord('q'):
    #     break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 (no detections), 147.3ms
# Speed: 2.9ms preprocess, 147.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 137.2ms
# Speed: 2.8ms preprocess, 137.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 133.4ms
# Speed: 3.1ms preprocess, 133.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 140.0ms
# Speed: 2.7ms preprocess, 140.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 142.4ms
# Speed: 2.0ms preprocess, 142.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 134.4ms
# Speed: 5.6ms preprocess, 134.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 140.3ms
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 25.5 MB/s eta 0:00:00
# ...
